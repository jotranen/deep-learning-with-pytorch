# %%
import matplotlib.pyplot as plt

# %%
r_values = [0.9826807379722595, 0.982612669467926, 0.9826892614364624, 0.982424795627594, 0.9828368425369263, 0.9824883937835693, 0.9830273389816284, 0.9831876754760742, 0.9826973676681519, 0.9824007749557495, 0.9821724891662598, 0.9827747344970703, 0.9830396175384521, 0.9822928309440613, 0.9822818040847778, 0.9822194576263428, 0.9825608730316162, 0.8537259697914124, 0.8658109307289124, 0.8820001482963562, 0.7879590392112732, 0.657745361328125, 0.8591563701629639]

# %%
plt.figure(figsize=(8,5))
plt.plot(r_values, label="R² score", marker='o')
plt.xlabel("Run index")
plt.ylabel("R²")
plt.title("R² across runs")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()
